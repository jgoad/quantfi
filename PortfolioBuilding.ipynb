# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
#%config InlineBackend.figure_format = 'svg'
import quantquoteminutely as qqm
import random

# %%
data = qqm.get_minutely_data('aapl','2012')

# %%
log_returns = pd.concat([np.log(data.close/data.close.shift(1)),
                             np.log(data.close/data.close.shift(60)),
                             np.log(data.close/data.close.shift(120)),
                             np.log(data.close/data.close.shift(360))],axis = 1)
log_returns.columns = ['log_returns_1','log_returns_60','log_returns_120','log_returns_360']

# %%
log_returns.log_returns_360.plot()

# %%
# have to dropna() or we get nothing!
pd.tools.plotting.autocorrelation_plot(log_returns['log_returns_360'].dropna())

# %%
pd.tools.plotting.autocorrelation_plot(log_returns['log_returns_60'].dropna())

# %%
pd.tools.plotting.autocorrelation_plot(log_returns['log_returns_1'].dropna())# even weeker autocorrelation...

# %%
data_daily = resample(data,'daily') # try autocorr on longer sampled data.
